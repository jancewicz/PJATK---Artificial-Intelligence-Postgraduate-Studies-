# %% [markdown]
# ### Data clustering using DBSCAN algorithm

# %%
from sklearn.datasets import make_blobs, make_moons, make_circles

# %%
blobs = make_blobs(n_samples=300, centers=3, cluster_std=[2.5, 0.5, 1.0], random_state=42)
moons = make_moons(n_samples=300, random_state=42, noise=0.1)
make_circles = make_circles(n_samples=300, factor=0.4, random_state=42, noise=0.08)
